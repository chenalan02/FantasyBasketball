# %%
import os
from os import path
import json
from yfpy import Data
from yfpy.logger import get_logger
from yfpy.query import YahooFantasySportsQuery
import datetime
import nba_api

# %%
auth_dir = r"auth/"
data_dir = r"data/"
league_id = r"101582"
game_id  = 428
with open(path.join(auth_dir, r"private.json")) as f:
    private = json.load(f)

data = Data(data_dir)

# %%
yahoo_query = YahooFantasySportsQuery(
    auth_dir,
    league_id,
    game_id = game_id,
    game_code= 'nba',
    offline=False,
    all_output_as_json_str=False,
    consumer_key=private["consumer_key"],
    consumer_secret=private["consumer_secret"],
    browser_callback=True
)

# %%
yahoo_query.get_current_user()
# Out:
# User({
#   "guid": "SNMYIY4VUSZTCOQZJRBGYRRWUQ"
# })

# %%
teams = yahoo_query.get_league_teams()

# %%
teams
# Out:
# [Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "adityapaluskar08@gmail.com",
#        "felo_score": 617,
#        "felo_tier": "silver",
#        "guid": "FZGQOROMVIFJ72PLVWS3E37G3U",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "is_commissioner": 0,
#        "manager_id": 1,
#        "nickname": "Aditya"
#      }
#    },
#    "name": "jokic and yutes2",
#    "number_of_moves": 5,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 1
#    },
#    "team_id": 1,
#    "team_key": "428.l.101582.t.1",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/9db8d77252590d9ad0b301c8f1b67f1b306fae1c03324af3eadd807c9b2f2972.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/1",
#    "waiver_priority": 9
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "aj.narayan@yahoo.com",
#        "felo_score": 600,
#        "felo_tier": "silver",
#        "guid": "32DKF2DVUY5UD2XYGLGGFSCSQE",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 2,
#        "nickname": "Aj"
#      }
#    },
#    "name": "Big Ballers",
#    "number_of_moves": 5,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 2
#    },
#    "team_id": 2,
#    "team_key": "428.l.101582.t.2",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/399890e265105320bfb1b3d0a1b826dc4b184a56acaec1d00250ff98640e2aa1.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/2",
#    "waiver_priority": 10
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "is_owned_by_current_login": 1,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "chenalan2002@gmail.com",
#        "felo_score": 649,
#        "felo_tier": "silver",
#        "guid": "SNMYIY4VUSZTCOQZJRBGYRRWUQ",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "is_current_login": 1,
#        "manager_id": 3,
#        "nickname": "Alan"
#      }
#    },
#    "name": "Alan's Okay Team",
#    "number_of_moves": 1,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 0
#    },
#    "team_id": 3,
#    "team_key": "428.l.101582.t.3",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://s.yimg.com/cv/apiv2/default/nba/nba_2_a.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/3",
#    "waiver_priority": 1
#  }),
#  Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "alexcampodonico12@gmail.com",
#        "felo_score": 597,
#        "felo_tier": "bronze",
#        "guid": "DWSMDTM4GUTQJP6IOEHMM43UAE",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 4,
#        "nickname": "Alex"
#      }
#    },
#    "name": "Adityapaluskar08@gmail.com",
#    "number_of_moves": 7,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 2
#    },
#    "team_id": 4,
#    "team_key": "428.l.101582.t.4",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/a7dab26ee2997e94c07d17172da89f9801dea11dbf785f94c3f9f92766a78fa7.jpg"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/4",
#    "waiver_priority": 8
#  }),
#  Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "adamdcunha@hotmail.com",
#        "felo_score": 751,
#        "felo_tier": "gold",
#        "guid": "543UJSPC2NCX4JV46RRBSSVZ67",
#        "image_url": "https://s.yimg.com/ag/images/bd837976-61f4-42dd-acf9-6edc52ad102eC8_64sq.jpg",
#        "manager_id": 5,
#        "nickname": "adam"
#      }
#    },
#    "name": "Team Samosa",
#    "number_of_moves": 3,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 1
#    },
#    "team_id": 5,
#    "team_key": "428.l.101582.t.5",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://s.yimg.com/cv/apiv2/default/nba/nba_1.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/5",
#    "waiver_priority": 4
#  }),
#  Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "aidancmathias@gmail.com",
#        "felo_score": 685,
#        "felo_tier": "silver",
#        "guid": "W6GCIVDBAXA7OFGGQ6BOIMELHE",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 6,
#        "nickname": "Aidan"
#      }
#    },
#    "name": "jokic and yutes",
#    "number_of_moves": 0,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 0
#    },
#    "team_id": 6,
#    "team_key": "428.l.101582.t.6",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/0e8288982e69f64a8daab332cc66a78ad0f2ad0919d8898dc744e3beb85e4439.jpg"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/6",
#    "waiver_priority": 3
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "pranav.pradhan1@gmail.com",
#        "felo_score": 577,
#        "felo_tier": "bronze",
#        "guid": "EX2WGQGZRPH6N5BBIXIWBEOOUA",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 7,
#        "nickname": "Pranav"
#      }
#    },
#    "name": "Pranav's Peerless Team",
#    "number_of_moves": 0,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 0
#    },
#    "team_id": 7,
#    "team_key": "428.l.101582.t.7",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://s.yimg.com/cv/apiv2/default/nba/nba_9_p.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/7",
#    "waiver_priority": 6
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "michaelcampo7202@gmail.com",
#        "felo_score": 599,
#        "felo_tier": "bronze",
#        "guid": "SRKN4SXIKVUHILFKOJNXL74LXE",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 8,
#        "nickname": "Michael"
#      }
#    },
#    "name": "Stupid mech eng",
#    "number_of_moves": 4,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 1
#    },
#    "team_id": 8,
#    "team_key": "428.l.101582.t.8",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/0ca48db100efe33463df54d7da0e5104c4366f7015ac1722a3c585659b873db2.jpg"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/8",
#    "waiver_priority": 12
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "ankitbatra2202@gmail.com",
#        "felo_score": 679,
#        "felo_tier": "silver",
#        "guid": "223PVWJCUDLUBNMGM6OF3QLOCY",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 9,
#        "nickname": "Ankit"
#      }
#    },
#    "name": "Rudy Gerbert’s",
#    "number_of_moves": 3,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 1
#    },
#    "team_id": 9,
#    "team_key": "428.l.101582.t.9",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://secure.gravatar.com/avatar/351b19ebe29d05699885367e4e8e1016?d=https%3A%2F%2Fs.yimg.com%2Fdh%2Fap%2Ffantasy%2Fimg%2Fprofile_96.png&s=96&r=r"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/9",
#    "waiver_priority": 7
#  }),
#  Team({
#    "division_id": 2,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "sahirbandali12@gmail.com",
#        "felo_score": 598,
#        "felo_tier": "bronze",
#        "guid": "WUVPNDMJUK7YLFXLAFR4OYOD7U",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 10,
#        "nickname": "sahir"
#      }
#    },
#    "name": "Ho You Fat",
#    "number_of_moves": 2,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 0
#    },
#    "team_id": 10,
#    "team_key": "428.l.101582.t.10",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://s.yimg.com/cv/apiv2/default/nba/nba_9_s.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/10",
#    "waiver_priority": 5
#  }),
#  Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "rahuq03@gmail.com",
#        "felo_score": 575,
#        "felo_tier": "bronze",
#        "guid": "MJMWPFK4EZG7PQAZFT6TMEK3Q4",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 11,
#        "nickname": "Rahik"
#      }
#    },
#    "name": "Raq Landia",
#    "number_of_moves": 6,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 2
#    },
#    "team_id": 11,
#    "team_key": "428.l.101582.t.11",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/3693d0371e3ca0bc5a0314f34dc351ad89326bfb65844a45e0082878745bcae9.jpg"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/11",
#    "waiver_priority": 2
#  }),
#  Team({
#    "division_id": 1,
#    "has_draft_grade": 0,
#    "league_scoring_type": "head",
#    "managers": {
#      "manager": {
#        "email": "ishaqsiddiqui133@gmail.com",
#        "felo_score": 705,
#        "felo_tier": "gold",
#        "guid": "KND25ILCKYXTUGUXCQDMYX22GA",
#        "image_url": "https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg",
#        "manager_id": 12,
#        "nickname": "Ishaq"
#      }
#    },
#    "name": "shaq’s squad",
#    "number_of_moves": 3,
#    "number_of_trades": 0,
#    "roster_adds": {
#      "coverage_type": "week",
#      "coverage_value": 2,
#      "value": 2
#    },
#    "team_id": 12,
#    "team_key": "428.l.101582.t.12",
#    "team_logos": {
#      "team_logo": {
#        "size": "large",
#        "url": "https://s.yimg.com/cv/apiv2/default/nba/nba_1_i.png"
#      }
#    },
#    "url": "https://basketball.fantasysports.yahoo.com/nba/101582/12",
#    "waiver_priority": 11
#  })]

# %% [markdown]
# Get players for a specific team

# %%
a = yahoo_query.get_team_info(12)

# %%
a.players
# Out:
# [Player({
#    "display_position": "PG,SG",
#    "editorial_player_key": "nba.p.6022",
#    "editorial_team_abbr": "OKC",
#    "editorial_team_full_name": "Oklahoma City Thunder",
#    "editorial_team_key": "nba.t.25",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/oklahoma-city/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/nbMydstCTRphMGMkOcJHQA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10192023/6022.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/nbMydstCTRphMGMkOcJHQA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10192023/6022.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Shai",
#      "ascii_last": "Gilgeous-Alexander",
#      "first": "Shai",
#      "full": "Shai Gilgeous-Alexander",
#      "last": "Gilgeous-Alexander"
#    },
#    "player_id": 6022,
#    "player_key": "428.p.6022",
#    "player_notes_last_timestamp": 1698895874,
#    "position_type": "P",
#    "primary_position": "PG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "PG"
#    },
#    "uniform_number": 2,
#    "url": "https://sports.yahoo.com/nba/players/6022"
#  }),
#  Player({
#    "display_position": "SG,SF,PF",
#    "editorial_player_key": "nba.p.6702",
#    "editorial_team_abbr": "OKC",
#    "editorial_team_full_name": "Oklahoma City Thunder",
#    "editorial_team_key": "nba.t.25",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/oklahoma-city/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/SkonboI6Vtsm0UZRQEKVnA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10192023/6702.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/SkonboI6Vtsm0UZRQEKVnA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10192023/6702.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Jalen",
#      "ascii_last": "Williams",
#      "first": "Jalen",
#      "full": "Jalen Williams",
#      "last": "Williams"
#    },
#    "player_id": 6702,
#    "player_key": "428.p.6702",
#    "player_notes_last_timestamp": 1698765995,
#    "position_type": "P",
#    "primary_position": "SG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "SG"
#    },
#    "uniform_number": 8,
#    "url": "https://sports.yahoo.com/nba/players/6702"
#  }),
#  Player({
#    "display_position": "SG,SF",
#    "editorial_player_key": "nba.p.5651",
#    "editorial_team_abbr": "CLE",
#    "editorial_team_full_name": "Cleveland Cavaliers",
#    "editorial_team_key": "nba.t.5",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/cleveland/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/os8GosCstE2byqM2gDLgMQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/5651.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/os8GosCstE2byqM2gDLgMQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/5651.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Caris",
#      "ascii_last": "LeVert",
#      "first": "Caris",
#      "full": "Caris LeVert",
#      "last": "LeVert"
#    },
#    "player_id": 5651,
#    "player_key": "428.p.5651",
#    "player_notes_last_timestamp": 1698893492,
#    "position_type": "P",
#    "primary_position": "SG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "G"
#    },
#    "uniform_number": 3,
#    "url": "https://sports.yahoo.com/nba/players/5651"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.3704",
#    "editorial_team_abbr": "LAL",
#    "editorial_team_full_name": "Los Angeles Lakers",
#    "editorial_team_key": "nba.t.13",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-lakers/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/yce8bJAlMFmWjlVBYhogoA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/3704.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/yce8bJAlMFmWjlVBYhogoA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/3704.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "LeBron",
#      "ascii_last": "James",
#      "first": "LeBron",
#      "full": "LeBron James",
#      "last": "James"
#    },
#    "player_id": 3704,
#    "player_key": "428.p.3704",
#    "player_notes_last_timestamp": 1698771038,
#    "position_type": "P",
#    "primary_position": "SF",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "SF"
#    },
#    "uniform_number": 23,
#    "url": "https://sports.yahoo.com/nba/players/3704"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.6514",
#    "editorial_team_abbr": "CLE",
#    "editorial_team_full_name": "Cleveland Cavaliers",
#    "editorial_team_key": "nba.t.5",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/cleveland/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/i.8a86zel7bRF.YcZf9BBQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/6514.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/i.8a86zel7bRF.YcZf9BBQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/6514.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Evan",
#      "ascii_last": "Mobley",
#      "first": "Evan",
#      "full": "Evan Mobley",
#      "last": "Mobley"
#    },
#    "player_id": 6514,
#    "player_key": "428.p.6514",
#    "player_notes_last_timestamp": 1698547147,
#    "position_type": "P",
#    "primary_position": "PF",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "PF"
#    },
#    "uniform_number": 4,
#    "url": "https://sports.yahoo.com/nba/players/6514"
#  }),
#  Player({
#    "display_position": "SG,SF",
#    "editorial_player_key": "nba.p.5637",
#    "editorial_team_abbr": "IND",
#    "editorial_team_full_name": "Indiana Pacers",
#    "editorial_team_key": "nba.t.11",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/indiana/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/4CQeGrGKH0k4Jw8DWdixkQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/5637.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/4CQeGrGKH0k4Jw8DWdixkQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/5637.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Buddy",
#      "ascii_last": "Hield",
#      "first": "Buddy",
#      "full": "Buddy Hield",
#      "last": "Hield"
#    },
#    "player_id": 5637,
#    "player_key": "428.p.5637",
#    "player_notes_last_timestamp": 1698284144,
#    "position_type": "P",
#    "primary_position": "SG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "F"
#    },
#    "uniform_number": 7,
#    "url": "https://sports.yahoo.com/nba/players/5637"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.6408",
#    "editorial_team_abbr": "DET",
#    "editorial_team_full_name": "Detroit Pistons",
#    "editorial_team_key": "nba.t.8",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/detroit/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/C4ix2Pw_w7jpcrkkSD7U6w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/6408.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/C4ix2Pw_w7jpcrkkSD7U6w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/6408.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Isaiah",
#      "ascii_last": "Stewart",
#      "first": "Isaiah",
#      "full": "Isaiah Stewart",
#      "last": "Stewart"
#    },
#    "player_id": 6408,
#    "player_key": "428.p.6408",
#    "player_notes_last_timestamp": 1698325509,
#    "position_type": "P",
#    "primary_position": "PF",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "C"
#    },
#    "uniform_number": 28,
#    "url": "https://sports.yahoo.com/nba/players/6408"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.6015",
#    "editorial_team_abbr": "MEM",
#    "editorial_team_full_name": "Memphis Grizzlies",
#    "editorial_team_key": "nba.t.29",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/memphis/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/aRupemBbPP4eyyJxpKnmtA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10252023/6015.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/aRupemBbPP4eyyJxpKnmtA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10252023/6015.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Jaren",
#      "ascii_last": "Jackson Jr.",
#      "first": "Jaren",
#      "full": "Jaren Jackson Jr.",
#      "last": "Jackson Jr."
#    },
#    "player_id": 6015,
#    "player_key": "428.p.6015",
#    "player_notes_last_timestamp": 1698733705,
#    "position_type": "P",
#    "primary_position": "PF",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "Util"
#    },
#    "uniform_number": 13,
#    "url": "https://sports.yahoo.com/nba/players/6015"
#  }),
#  Player({
#    "display_position": "C",
#    "editorial_player_key": "nba.p.6558",
#    "editorial_team_abbr": "HOU",
#    "editorial_team_full_name": "Houston Rockets",
#    "editorial_team_key": "nba.t.10",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/houston/",
#    "eligible_positions": [
#      "C"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Z9g_mDm1yAEDFCym.P3YCg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/6558.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Z9g_mDm1yAEDFCym.P3YCg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/6558.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Alperen",
#      "ascii_last": "Sengun",
#      "first": "Alperen",
#      "full": "Alperen Sengun",
#      "last": "Sengun"
#    },
#    "player_id": 6558,
#    "player_key": "428.p.6558",
#    "player_notes_last_timestamp": 1698712928,
#    "position_type": "P",
#    "primary_position": "C",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "Util"
#    },
#    "uniform_number": 28,
#    "url": "https://sports.yahoo.com/nba/players/6558"
#  }),
#  Player({
#    "display_position": "SG,SF",
#    "editorial_player_key": "nba.p.5159",
#    "editorial_team_abbr": "DEN",
#    "editorial_team_full_name": "Denver Nuggets",
#    "editorial_team_key": "nba.t.7",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/denver/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/3F6fxSDO.7NniGqLFJXEcg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/5159.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/3F6fxSDO.7NniGqLFJXEcg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/5159.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Kentavious",
#      "ascii_last": "Caldwell-Pope",
#      "first": "Kentavious",
#      "full": "Kentavious Caldwell-Pope",
#      "last": "Caldwell-Pope"
#    },
#    "player_id": 5159,
#    "player_key": "428.p.5159",
#    "player_notes_last_timestamp": 1698770476,
#    "position_type": "P",
#    "primary_position": "SG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "BN"
#    },
#    "uniform_number": 5,
#    "url": "https://sports.yahoo.com/nba/players/5159"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.5292",
#    "editorial_team_abbr": "GSW",
#    "editorial_team_full_name": "Golden State Warriors",
#    "editorial_team_key": "nba.t.9",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/golden-state/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/KLmCkQymQaRVFo4A3UsKNA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/5292.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/KLmCkQymQaRVFo4A3UsKNA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/5292.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Andrew",
#      "ascii_last": "Wiggins",
#      "first": "Andrew",
#      "full": "Andrew Wiggins",
#      "last": "Wiggins"
#    },
#    "player_id": 5292,
#    "player_key": "428.p.5292",
#    "player_notes_last_timestamp": 1698682942,
#    "position_type": "P",
#    "primary_position": "SF",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "BN"
#    },
#    "uniform_number": 22,
#    "url": "https://sports.yahoo.com/nba/players/5292"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.6433",
#    "editorial_team_abbr": "SAS",
#    "editorial_team_full_name": "San Antonio Spurs",
#    "editorial_team_key": "nba.t.24",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/san-antonio/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/7i1xx5PiPWuYZ8OfC4e03A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/6433.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/7i1xx5PiPWuYZ8OfC4e03A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/6433.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Tre",
#      "ascii_last": "Jones",
#      "first": "Tre",
#      "full": "Tre Jones",
#      "last": "Jones"
#    },
#    "player_id": 6433,
#    "player_key": "428.p.6433",
#    "player_notes_last_timestamp": 1698685366,
#    "position_type": "P",
#    "primary_position": "PG",
#    "selected_position": {
#      "coverage_type": "date",
#      "date": "2023-11-01",
#      "is_flex": 0,
#      "position": "BN"
#    },
#    "uniform_number": 33,
#    "url": "https://sports.yahoo.com/nba/players/6433"
#  })]

# %% [markdown]
# Get list of all players, includes injury status and primary position

# %%
a = yahoo_query.get_league_players(player_count_start=0)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\chena\Desktop\FantasyBasketball\test.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> a = yahoo_query.get_league_players(player_count_start=0)
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:1374, in YahooFantasySportsQuery.get_league_players(self, player_count_limit, player_count_start, is_retry)
#    1370 while not all_players_retrieved:
#    1372     try:
#    1373         league_player_query_data = self.query(
# -> 1374             f"https://fantasysports.yahooapis.com/fantasy/v2/league/{self.get_league_key()}/players;"
#    1375             f"start={league_player_count};count={league_player_retrieval_limit if not is_retry else 1}",
#    1376             ["league", "players"]
#    1377         )
#    1379         league_players = (league_player_query_data if isinstance(league_player_query_data, list) else
#    1380                           [league_player_query_data])
#    1381         league_player_count_from_query = len(league_players)
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:774, in YahooFantasySportsQuery.get_league_key(self, season)
#     772     return f"{self.get_game_key_by_season(season)}.l.{self.league_id}"
#     773 elif self.game_id:
# --> 774     return f"{self.get_game_metadata_by_game_id(self.game_id).game_key}.l.{self.league_id}"
#     775 else:
#     776     logger.warning(
#     777         "No game id or season/year provided, defaulting to current fantasy season.")
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:603, in YahooFantasySportsQuery.get_game_metadata_by_game_id(self, game_id)
#     575 def get_game_metadata_by_game_id(self, game_id: int) -> Game:
#     576     """Retrieve game metadata for specific game by ID.
#     577
#     578     Args:
#    (...)
#     601
#     602     """
# --> 603     return self.query(
#     604         f"https://fantasysports.yahooapis.com/fantasy/v2/game/{game_id}/metadata",
#     605         ["game"],
#     606         Game
#     607     )
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:262, in YahooFantasySportsQuery.query(self, url, data_key_list, data_type_class, sort_function)
#     243 """Base query class to retrieve requested data from the Yahoo fantasy sports REST API.
#     244
#     245 Args:
#    (...)
#     259
#     260 """
#     261 if not self.offline:
# --> 262     response = self.get_response(url)
#     263     raw_response_data = response.json().get(self.fantasy_content_data_field)
#     265     # iterate through list of data keys and drill down to final desired data field
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:185, in YahooFantasySportsQuery.get_response(self, url)
#     183 # when you exceed Yahoo's allowed data request limits, they throw a request status code of 999
#     184 if status_code == 999:
# --> 185     raise HTTPError("Yahoo data unavailable due to rate limiting. Please try again later.")
#     187 if status_code == 401:
#     188     self._authenticate()
#
# HTTPError: Yahoo data unavailable due to rate limiting. Please try again later.

# %%
a
# Out:
# [Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.3704",
#    "editorial_team_abbr": "LAL",
#    "editorial_team_full_name": "Los Angeles Lakers",
#    "editorial_team_key": "nba.t.13",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-lakers/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/yce8bJAlMFmWjlVBYhogoA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/3704.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/yce8bJAlMFmWjlVBYhogoA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/3704.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "LeBron",
#      "ascii_last": "James",
#      "first": "LeBron",
#      "full": "LeBron James",
#      "last": "James"
#    },
#    "player_id": 3704,
#    "player_key": "428.p.3704",
#    "player_notes_last_timestamp": 1698907829,
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 23,
#    "url": "https://sports.yahoo.com/nba/players/3704"
#  }),
#  Player({
#    "display_position": "SF",
#    "editorial_player_key": "nba.p.3826",
#    "editorial_team_abbr": "GSW",
#    "editorial_team_full_name": "Golden State Warriors",
#    "editorial_team_key": "nba.t.9",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/golden-state/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/b.jR0HAAjJJfDZ6mibqcZw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10042022/3826.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/b.jR0HAAjJJfDZ6mibqcZw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10042022/3826.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Andre",
#      "ascii_last": "Iguodala",
#      "first": "Andre",
#      "full": "Andre Iguodala",
#      "last": "Iguodala"
#    },
#    "player_id": 3826,
#    "player_key": "428.p.3826",
#    "position_type": "P",
#    "primary_position": "SF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 9,
#    "url": "https://sports.yahoo.com/nba/players/3826"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.3930",
#    "editorial_team_abbr": "GSW",
#    "editorial_team_full_name": "Golden State Warriors",
#    "editorial_team_key": "nba.t.9",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/golden-state/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/SPiSd5BWLCT3lbuL4SBUUw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/3930.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/SPiSd5BWLCT3lbuL4SBUUw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/3930.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Chris",
#      "ascii_last": "Paul",
#      "first": "Chris",
#      "full": "Chris Paul",
#      "last": "Paul"
#    },
#    "player_id": 3930,
#    "player_key": "428.p.3930",
#    "player_notes_last_timestamp": 1698616812,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 3,
#    "url": "https://sports.yahoo.com/nba/players/3930"
#  }),
#  Player({
#    "display_position": "SF",
#    "editorial_player_key": "nba.p.4136",
#    "editorial_team_abbr": "UTA",
#    "editorial_team_full_name": "Utah Jazz",
#    "editorial_team_key": "nba.t.26",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/utah/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/NHyinrUZ0hmZ2r9HIo3NZQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/4136.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/NHyinrUZ0hmZ2r9HIo3NZQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/4136.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Rudy",
#      "ascii_last": "Gay",
#      "first": "Rudy",
#      "full": "Rudy Gay",
#      "last": "Gay"
#    },
#    "player_id": 4136,
#    "player_key": "428.p.4136",
#    "position_type": "P",
#    "primary_position": "SF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 22,
#    "url": "https://sports.yahoo.com/nba/players/4136"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4152",
#    "editorial_team_abbr": "MIA",
#    "editorial_team_full_name": "Miami Heat",
#    "editorial_team_key": "nba.t.14",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/miami/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Hqr0_K3qZzUzPBm7TEZUVA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4152.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Hqr0_K3qZzUzPBm7TEZUVA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4152.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Kyle",
#      "ascii_last": "Lowry",
#      "first": "Kyle",
#      "full": "Kyle Lowry",
#      "last": "Lowry"
#    },
#    "player_id": 4152,
#    "player_key": "428.p.4152",
#    "player_notes_last_timestamp": 1698465083,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 7,
#    "url": "https://sports.yahoo.com/nba/players/4152"
#  }),
#  Player({
#    "display_position": "SF",
#    "editorial_player_key": "nba.p.4163",
#    "editorial_team_abbr": "LAC",
#    "editorial_team_full_name": "LA Clippers",
#    "editorial_team_key": "nba.t.12",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-clippers/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/BYrPQGHr2O6GJCHdvlWJTQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4163.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/BYrPQGHr2O6GJCHdvlWJTQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4163.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "P.J.",
#      "ascii_last": "Tucker",
#      "first": "P.J.",
#      "full": "P.J. Tucker",
#      "last": "Tucker"
#    },
#    "player_id": 4163,
#    "player_key": "428.p.4163",
#    "player_notes_last_timestamp": 1698870013,
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 17,
#    "url": "https://sports.yahoo.com/nba/players/4163"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.4244",
#    "editorial_team_abbr": "PHX",
#    "editorial_team_full_name": "Phoenix Suns",
#    "editorial_team_key": "nba.t.21",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/phoenix/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/PLdnakgk0NIQX.UtS5CN8A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4244.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/PLdnakgk0NIQX.UtS5CN8A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4244.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Kevin",
#      "ascii_last": "Durant",
#      "first": "Kevin",
#      "full": "Kevin Durant",
#      "last": "Durant"
#    },
#    "player_id": 4244,
#    "player_key": "428.p.4244",
#    "player_notes_last_timestamp": 1698847204,
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 35,
#    "url": "https://sports.yahoo.com/nba/players/4244"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4245",
#    "editorial_team_abbr": "BOS",
#    "editorial_team_full_name": "Boston Celtics",
#    "editorial_team_key": "nba.t.2",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/boston/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/tc7VtmPtCQ9.uCWN3l6a4g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10102023/4245.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/tc7VtmPtCQ9.uCWN3l6a4g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10102023/4245.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Al",
#      "ascii_last": "Horford",
#      "first": "Al",
#      "full": "Al Horford",
#      "last": "Horford"
#    },
#    "player_id": 4245,
#    "player_key": "428.p.4245",
#    "player_notes_last_timestamp": 1698330897,
#    "position_type": "P",
#    "primary_position": "PF",
#    "uniform_number": 42,
#    "url": "https://sports.yahoo.com/nba/players/4245"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4246",
#    "editorial_team_abbr": "MIN",
#    "editorial_team_full_name": "Minnesota Timberwolves",
#    "editorial_team_key": "nba.t.16",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/minnesota/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Bl07LZ.0AelsbRymV3fBmQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4246.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Bl07LZ.0AelsbRymV3fBmQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4246.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Mike",
#      "ascii_last": "Conley",
#      "first": "Mike",
#      "full": "Mike Conley",
#      "last": "Conley"
#    },
#    "player_id": 4246,
#    "player_key": "428.p.4246",
#    "player_notes_last_timestamp": 1698186517,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 10,
#    "url": "https://sports.yahoo.com/nba/players/4246"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4247",
#    "editorial_team_abbr": "HOU",
#    "editorial_team_full_name": "Houston Rockets",
#    "editorial_team_key": "nba.t.10",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/houston/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/c8YDUcFLVn9uE7.sE5jcYQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/4247.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/c8YDUcFLVn9uE7.sE5jcYQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/4247.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Jeff",
#      "ascii_last": "Green",
#      "first": "Jeff",
#      "full": "Jeff Green",
#      "last": "Green"
#    },
#    "player_id": 4247,
#    "player_key": "428.p.4247",
#    "position_type": "P",
#    "primary_position": "PF",
#    "uniform_number": 32,
#    "url": "https://sports.yahoo.com/nba/players/4247"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4290",
#    "editorial_team_abbr": "TOR",
#    "editorial_team_full_name": "Toronto Raptors",
#    "editorial_team_key": "nba.t.28",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/toronto/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/VCtmyQDEaxg9xdj7DV_kRg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/4290.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/VCtmyQDEaxg9xdj7DV_kRg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/4290.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Thaddeus",
#      "ascii_last": "Young",
#      "first": "Thaddeus",
#      "full": "Thaddeus Young",
#      "last": "Young"
#    },
#    "player_id": 4290,
#    "player_key": "428.p.4290",
#    "position_type": "P",
#    "primary_position": "PF",
#    "uniform_number": 21,
#    "url": "https://sports.yahoo.com/nba/players/4290"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4387",
#    "editorial_team_abbr": "MEM",
#    "editorial_team_full_name": "Memphis Grizzlies",
#    "editorial_team_key": "nba.t.29",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/memphis/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/0ZnYY3eH0hjXtQCpeuCXeg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10252023/4387.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/0ZnYY3eH0hjXtQCpeuCXeg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10252023/4387.png",
#    "injury_note": "Knee",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Derrick",
#      "ascii_last": "Rose",
#      "first": "Derrick",
#      "full": "Derrick Rose",
#      "last": "Rose"
#    },
#    "player_id": 4387,
#    "player_key": "428.p.4387",
#    "player_notes_last_timestamp": 1698882334,
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "INJ",
#    "status_full": "Injured (IL-eligible)",
#    "uniform_number": 23,
#    "url": "https://sports.yahoo.com/nba/players/4387"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4390",
#    "editorial_team_abbr": "LAC",
#    "editorial_team_full_name": "LA Clippers",
#    "editorial_team_key": "nba.t.12",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-clippers/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/WVabkXoLG4hLQr3OM.QNBA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10202023/4390.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/WVabkXoLG4hLQr3OM.QNBA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10202023/4390.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Russell",
#      "ascii_last": "Westbrook",
#      "first": "Russell",
#      "full": "Russell Westbrook",
#      "last": "Westbrook"
#    },
#    "player_id": 4390,
#    "player_key": "428.p.4390",
#    "player_notes_last_timestamp": 1698910725,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 0,
#    "url": "https://sports.yahoo.com/nba/players/4390"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4391",
#    "editorial_team_abbr": "MIA",
#    "editorial_team_full_name": "Miami Heat",
#    "editorial_team_key": "nba.t.14",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/miami/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/FqDc2prGZUdXfjMn95LBtw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4391.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/FqDc2prGZUdXfjMn95LBtw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4391.png",
#    "injury_note": "Shoulder",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Kevin",
#      "ascii_last": "Love",
#      "first": "Kevin",
#      "full": "Kevin Love",
#      "last": "Love"
#    },
#    "player_id": 4391,
#    "player_key": "428.p.4391",
#    "player_notes_last_timestamp": 1698877912,
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "GTD",
#    "status_full": "Game Time Decision",
#    "uniform_number": 42,
#    "url": "https://sports.yahoo.com/nba/players/4391"
#  }),
#  Player({
#    "display_position": "SF",
#    "editorial_player_key": "nba.p.4468",
#    "editorial_team_abbr": "WAS",
#    "editorial_team_full_name": "Washington Wizards",
#    "editorial_team_key": "nba.t.27",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/washington/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/lf.WyiW3VTMs405z8dLJ7g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10112023/4468.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/lf.WyiW3VTMs405z8dLJ7g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10112023/4468.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Danilo",
#      "ascii_last": "Gallinari",
#      "first": "Danilo",
#      "full": "Danilo Gallinari",
#      "last": "Gallinari"
#    },
#    "player_id": 4468,
#    "player_key": "428.p.4468",
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 88,
#    "url": "https://sports.yahoo.com/nba/players/4468"
#  }),
#  Player({
#    "display_position": "SG,SF",
#    "editorial_player_key": "nba.p.4469",
#    "editorial_team_abbr": "PHX",
#    "editorial_team_full_name": "Phoenix Suns",
#    "editorial_team_key": "nba.t.21",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/phoenix/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/TlN_tx27BNwHLDufLoi3EQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4469.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/TlN_tx27BNwHLDufLoi3EQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4469.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Eric",
#      "ascii_last": "Gordon",
#      "first": "Eric",
#      "full": "Eric Gordon",
#      "last": "Gordon"
#    },
#    "player_id": 4469,
#    "player_key": "428.p.4469",
#    "player_notes_last_timestamp": 1698588971,
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 23,
#    "url": "https://sports.yahoo.com/nba/players/4469"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4471",
#    "editorial_team_abbr": "HOU",
#    "editorial_team_full_name": "Houston Rockets",
#    "editorial_team_key": "nba.t.10",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/houston/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/rEmMvVG3GH1a3pQB3KG.0A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10052022/4471.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/rEmMvVG3GH1a3pQB3KG.0A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10052022/4471.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "D.J.",
#      "ascii_last": "Augustin",
#      "first": "D.J.",
#      "full": "D.J. Augustin",
#      "last": "Augustin"
#    },
#    "player_id": 4471,
#    "player_key": "428.p.4471",
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 14,
#    "url": "https://sports.yahoo.com/nba/players/4471"
#  }),
#  Player({
#    "display_position": "C",
#    "editorial_player_key": "nba.p.4472",
#    "editorial_team_abbr": "MIL",
#    "editorial_team_full_name": "Milwaukee Bucks",
#    "editorial_team_key": "nba.t.15",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/milwaukee/",
#    "eligible_positions": [
#      "C"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/v2Wt1WkqLCNmGD7HUQqAlw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4472.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/v2Wt1WkqLCNmGD7HUQqAlw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4472.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Brook",
#      "ascii_last": "Lopez",
#      "first": "Brook",
#      "full": "Brook Lopez",
#      "last": "Lopez"
#    },
#    "player_id": 4472,
#    "player_key": "428.p.4472",
#    "player_notes_last_timestamp": 1698429034,
#    "position_type": "P",
#    "primary_position": "C",
#    "uniform_number": 11,
#    "url": "https://sports.yahoo.com/nba/players/4472"
#  }),
#  Player({
#    "display_position": "C",
#    "editorial_player_key": "nba.p.4477",
#    "editorial_team_abbr": "MIL",
#    "editorial_team_full_name": "Milwaukee Bucks",
#    "editorial_team_key": "nba.t.15",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/milwaukee/",
#    "eligible_positions": [
#      "C"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/aAmyC6MWO1B5_qusZTyy0w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4477.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/aAmyC6MWO1B5_qusZTyy0w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/4477.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Robin",
#      "ascii_last": "Lopez",
#      "first": "Robin",
#      "full": "Robin Lopez",
#      "last": "Lopez"
#    },
#    "player_id": 4477,
#    "player_key": "428.p.4477",
#    "position_type": "P",
#    "primary_position": "C",
#    "uniform_number": 42,
#    "url": "https://sports.yahoo.com/nba/players/4477"
#  }),
#  Player({
#    "display_position": "C",
#    "editorial_player_key": "nba.p.4480",
#    "editorial_team_abbr": "SAC",
#    "editorial_team_full_name": "Sacramento Kings",
#    "editorial_team_key": "nba.t.23",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/sacramento/",
#    "eligible_positions": [
#      "C"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/y889.EtyDOKWHaec4hHCPg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/4480.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/y889.EtyDOKWHaec4hHCPg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10162023/4480.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "JaVale",
#      "ascii_last": "McGee",
#      "first": "JaVale",
#      "full": "JaVale McGee",
#      "last": "McGee"
#    },
#    "player_id": 4480,
#    "player_key": "428.p.4480",
#    "player_notes_last_timestamp": 1698281194,
#    "position_type": "P",
#    "primary_position": "C",
#    "uniform_number": "00",
#    "url": "https://sports.yahoo.com/nba/players/4480"
#  }),
#  Player({
#    "display_position": "PF",
#    "editorial_player_key": "nba.p.4486",
#    "editorial_team_abbr": "IND",
#    "editorial_team_full_name": "Indiana Pacers",
#    "editorial_team_key": "nba.t.11",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/indiana/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Bfn7HTRyyKESoqKhwno_9A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4486.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Bfn7HTRyyKESoqKhwno_9A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4486.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Serge",
#      "ascii_last": "Ibaka",
#      "first": "Serge",
#      "full": "Serge Ibaka",
#      "last": "Ibaka"
#    },
#    "player_id": 4486,
#    "player_key": "428.p.4486",
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": null,
#    "url": "https://sports.yahoo.com/nba/players/4486"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.4487",
#    "editorial_team_abbr": "PHI",
#    "editorial_team_full_name": "Philadelphia 76ers",
#    "editorial_team_key": "nba.t.20",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/philadelphia/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/2S9vZZpYKQdkpmi2Z6zePQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10202023/4487.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/2S9vZZpYKQdkpmi2Z6zePQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10202023/4487.png",
#    "injury_note": "Personal",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Nicolas",
#      "ascii_last": "Batum",
#      "first": "Nicolas",
#      "full": "Nicolas Batum",
#      "last": "Batum"
#    },
#    "player_id": 4487,
#    "player_key": "428.p.4487",
#    "player_notes_last_timestamp": 1698871567,
#    "position_type": "P",
#    "primary_position": "SF",
#    "status": "O",
#    "status_full": "Out (short-term injury)",
#    "uniform_number": 40,
#    "url": "https://sports.yahoo.com/nba/players/4487"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4488",
#    "editorial_team_abbr": "IND",
#    "editorial_team_full_name": "Indiana Pacers",
#    "editorial_team_key": "nba.t.11",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/indiana/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Q_SX2nLS6N516qlELtlwAw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4488.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Q_SX2nLS6N516qlELtlwAw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4488.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "George",
#      "ascii_last": "Hill",
#      "first": "George",
#      "full": "George Hill",
#      "last": "Hill"
#    },
#    "player_id": 4488,
#    "player_key": "428.p.4488",
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 7,
#    "url": "https://sports.yahoo.com/nba/players/4488"
#  }),
#  Player({
#    "display_position": "C",
#    "editorial_player_key": "nba.p.4497",
#    "editorial_team_abbr": "DEN",
#    "editorial_team_full_name": "Denver Nuggets",
#    "editorial_team_key": "nba.t.7",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/denver/",
#    "eligible_positions": [
#      "C"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/S3H5rWT_m9dj66b9Ucdw2w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/4497.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/S3H5rWT_m9dj66b9Ucdw2w--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10182023/4497.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "DeAndre",
#      "ascii_last": "Jordan",
#      "first": "DeAndre",
#      "full": "DeAndre Jordan",
#      "last": "Jordan"
#    },
#    "player_id": 4497,
#    "player_key": "428.p.4497",
#    "position_type": "P",
#    "primary_position": "C",
#    "uniform_number": 6,
#    "url": "https://sports.yahoo.com/nba/players/4497"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4507",
#    "editorial_team_abbr": "CHI",
#    "editorial_team_full_name": "Chicago Bulls",
#    "editorial_team_key": "nba.t.4",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/chicago/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/vSXghMBmwtDICkRYMFItmA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4507.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/vSXghMBmwtDICkRYMFItmA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4507.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Goran",
#      "ascii_last": "Dragic",
#      "first": "Goran",
#      "full": "Goran Dragic",
#      "last": "Dragic"
#    },
#    "player_id": 4507,
#    "player_key": "428.p.4507",
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 31,
#    "url": "https://sports.yahoo.com/nba/players/4507"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4561",
#    "editorial_team_abbr": "BOS",
#    "editorial_team_full_name": "Boston Celtics",
#    "editorial_team_key": "nba.t.2",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/boston/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/UnUWIzoxF2o8acAT29Vm3g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10062022/4561.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/UnUWIzoxF2o8acAT29Vm3g--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10062022/4561.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Blake",
#      "ascii_last": "Griffin",
#      "first": "Blake",
#      "full": "Blake Griffin",
#      "last": "Griffin"
#    },
#    "player_id": 4561,
#    "player_key": "428.p.4561",
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 91,
#    "url": "https://sports.yahoo.com/nba/players/4561"
#  }),
#  Player({
#    "display_position": "PG,SG",
#    "editorial_player_key": "nba.p.4563",
#    "editorial_team_abbr": "LAC",
#    "editorial_team_full_name": "LA Clippers",
#    "editorial_team_key": "nba.t.12",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-clippers/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/z_l_.lr0e2TmkpDxDtYWjw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10312023/4563.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/z_l_.lr0e2TmkpDxDtYWjw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10312023/4563.png",
#    "injury_note": "Not Injury Related",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "James",
#      "ascii_last": "Harden",
#      "first": "James",
#      "full": "James Harden",
#      "last": "Harden"
#    },
#    "player_id": 4563,
#    "player_key": "428.p.4563",
#    "player_notes_last_timestamp": 1698850463,
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "INJ",
#    "status_full": "Injured (IL-eligible)",
#    "uniform_number": 1,
#    "url": "https://sports.yahoo.com/nba/players/4563"
#  }),
#  Player({
#    "display_position": "PG,SG",
#    "editorial_player_key": "nba.p.4610",
#    "editorial_team_abbr": "CLE",
#    "editorial_team_full_name": "Cleveland Cavaliers",
#    "editorial_team_key": "nba.t.5",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/cleveland/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/xDPFdIegkq81P_h1juOiDg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10042022/4610.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/xDPFdIegkq81P_h1juOiDg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10042022/4610.png",
#    "injury_note": "Personal",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Ricky",
#      "ascii_last": "Rubio",
#      "first": "Ricky",
#      "full": "Ricky Rubio",
#      "last": "Rubio"
#    },
#    "player_id": 4610,
#    "player_key": "428.p.4610",
#    "position_type": "P",
#    "primary_position": "PG",
#    "status": "INJ",
#    "status_full": "Injured (IL-eligible)",
#    "uniform_number": 13,
#    "url": "https://sports.yahoo.com/nba/players/4610"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4612",
#    "editorial_team_abbr": "GSW",
#    "editorial_team_full_name": "Golden State Warriors",
#    "editorial_team_key": "nba.t.9",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/golden-state/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/e.67WOdUaugo7ETW6CemfA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/4612.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/e.67WOdUaugo7ETW6CemfA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10132023/4612.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Stephen",
#      "ascii_last": "Curry",
#      "first": "Stephen",
#      "full": "Stephen Curry",
#      "last": "Curry"
#    },
#    "player_id": 4612,
#    "player_key": "428.p.4612",
#    "player_notes_last_timestamp": 1698927539,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 30,
#    "url": "https://sports.yahoo.com/nba/players/4612"
#  }),
#  Player({
#    "display_position": "SG,SF",
#    "editorial_player_key": "nba.p.4614",
#    "editorial_team_abbr": "CHI",
#    "editorial_team_full_name": "Chicago Bulls",
#    "editorial_team_key": "nba.t.4",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/chicago/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/HZpm3ER8WY69XSXo49uraQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4614.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/HZpm3ER8WY69XSXo49uraQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4614.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "DeMar",
#      "ascii_last": "DeRozan",
#      "first": "DeMar",
#      "full": "DeMar DeRozan",
#      "last": "DeRozan"
#    },
#    "player_id": 4614,
#    "player_key": "428.p.4614",
#    "player_notes_last_timestamp": 1698741249,
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 11,
#    "url": "https://sports.yahoo.com/nba/players/4614"
#  }),
#  Player({
#    "display_position": "PF",
#    "editorial_player_key": "nba.p.4621",
#    "editorial_team_abbr": "IND",
#    "editorial_team_full_name": "Indiana Pacers",
#    "editorial_team_key": "nba.t.11",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/indiana/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/gSXO05dS0XI6B8OdShIYUg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10052022/4621.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/gSXO05dS0XI6B8OdShIYUg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10052022/4621.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "James",
#      "ascii_last": "Johnson",
#      "first": "James",
#      "full": "James Johnson",
#      "last": "Johnson"
#    },
#    "player_id": 4621,
#    "player_key": "428.p.4621",
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 16,
#    "url": "https://sports.yahoo.com/nba/players/4621"
#  }),
#  Player({
#    "display_position": "PG,SG",
#    "editorial_player_key": "nba.p.4622",
#    "editorial_team_abbr": "BOS",
#    "editorial_team_full_name": "Boston Celtics",
#    "editorial_team_key": "nba.t.2",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/boston/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/B05NAvsLPxBbfVIoaXoUDw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4622.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/B05NAvsLPxBbfVIoaXoUDw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10032022/4622.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Jrue",
#      "ascii_last": "Holiday",
#      "first": "Jrue",
#      "full": "Jrue Holiday",
#      "last": "Holiday"
#    },
#    "player_id": 4622,
#    "player_key": "428.p.4622",
#    "player_notes_last_timestamp": 1698759323,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 4,
#    "url": "https://sports.yahoo.com/nba/players/4622"
#  }),
#  Player({
#    "display_position": "PF,C",
#    "editorial_player_key": "nba.p.4631",
#    "editorial_team_abbr": "WAS",
#    "editorial_team_full_name": "Washington Wizards",
#    "editorial_team_key": "nba.t.27",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/washington/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/O9lIQ69Q4NpiskZ1qH62Og--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10112023/4631.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/O9lIQ69Q4NpiskZ1qH62Og--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10112023/4631.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Taj",
#      "ascii_last": "Gibson",
#      "first": "Taj",
#      "full": "Taj Gibson",
#      "last": "Gibson"
#    },
#    "player_id": 4631,
#    "player_key": "428.p.4631",
#    "player_notes_last_timestamp": 1698095092,
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 67,
#    "url": "https://sports.yahoo.com/nba/players/4631"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.4647",
#    "editorial_team_abbr": "PHI",
#    "editorial_team_full_name": "Philadelphia 76ers",
#    "editorial_team_key": "nba.t.20",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/philadelphia/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/mbJLAvAOpuMCfJl0YQv0iA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4647.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/mbJLAvAOpuMCfJl0YQv0iA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4647.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Patrick",
#      "ascii_last": "Beverley",
#      "first": "Patrick",
#      "full": "Patrick Beverley",
#      "last": "Beverley"
#    },
#    "player_id": 4647,
#    "player_key": "428.p.4647",
#    "player_notes_last_timestamp": 1698687287,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 22,
#    "url": "https://sports.yahoo.com/nba/players/4647"
#  }),
#  Player({
#    "display_position": "SG",
#    "editorial_player_key": "nba.p.4651",
#    "editorial_team_abbr": "PHI",
#    "editorial_team_full_name": "Philadelphia 76ers",
#    "editorial_team_key": "nba.t.20",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/philadelphia/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/tzK9uGa1jY8PYiJiAGpRRA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4651.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/tzK9uGa1jY8PYiJiAGpRRA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/4651.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
# ...
#    "eligible_positions": [
#      "SG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/fmAB8nm6D0cJ1dEeOcdZbw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/10133.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/fmAB8nm6D0cJ1dEeOcdZbw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/10133.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Markquis",
#      "ascii_last": "Nowell",
#      "first": "Markquis",
#      "full": "Markquis Nowell",
#      "last": "Nowell"
#    },
#    "player_id": 10133,
#    "player_key": "428.p.10133",
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 24,
#    "url": "https://sports.yahoo.com/nba/players/10133"
#  }),
#  Player({
#    "display_position": "SF",
#    "editorial_player_key": "nba.p.10134",
#    "editorial_team_abbr": "NYK",
#    "editorial_team_full_name": "New York Knicks",
#    "editorial_team_key": "nba.t.18",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/new-york/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/XMMDNZdRLJ2Hf4t8_pP6qQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10232023/10134.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/XMMDNZdRLJ2Hf4t8_pP6qQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10232023/10134.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Jaylen",
#      "ascii_last": "Martin",
#      "first": "Jaylen",
#      "full": "Jaylen Martin",
#      "last": "Martin"
#    },
#    "player_id": 10134,
#    "player_key": "428.p.10134",
#    "position_type": "P",
#    "primary_position": "SF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 16,
#    "url": "https://sports.yahoo.com/nba/players/10134"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.10135",
#    "editorial_team_abbr": "PHI",
#    "editorial_team_full_name": "Philadelphia 76ers",
#    "editorial_team_key": "nba.t.20",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/philadelphia/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/YUFv6rfVim77n6zGocwTHQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10135.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/YUFv6rfVim77n6zGocwTHQ--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10135.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Terquavion",
#      "ascii_last": "Smith",
#      "first": "Terquavion",
#      "full": "Terquavion Smith",
#      "last": "Smith"
#    },
#    "player_id": 10135,
#    "player_key": "428.p.10135",
#    "player_notes_last_timestamp": 1698270823,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 23,
#    "url": "https://sports.yahoo.com/nba/players/10135"
#  }),
#  Player({
#    "display_position": "PF",
#    "editorial_player_key": "nba.p.10136",
#    "editorial_team_abbr": "PHI",
#    "editorial_team_full_name": "Philadelphia 76ers",
#    "editorial_team_key": "nba.t.20",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/philadelphia/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/Kr_BbrsErKW5H9tiTZg4ZA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10136.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/Kr_BbrsErKW5H9tiTZg4ZA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10136.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Azuolas",
#      "ascii_last": "Tubelis",
#      "first": "Azuolas",
#      "full": "Azuolas Tubelis",
#      "last": "Tubelis"
#    },
#    "player_id": 10136,
#    "player_key": "428.p.10136",
#    "player_notes_last_timestamp": 1698254612,
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 20,
#    "url": "https://sports.yahoo.com/nba/players/10136"
#  }),
#  Player({
#    "display_position": "PF",
#    "editorial_player_key": "nba.p.10141",
#    "editorial_team_abbr": "MIL",
#    "editorial_team_full_name": "Milwaukee Bucks",
#    "editorial_team_key": "nba.t.15",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/milwaukee/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/FdAHXdSstUmiwUBbnTrPCA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10141.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/FdAHXdSstUmiwUBbnTrPCA--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10141.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Drew",
#      "ascii_last": "Timme",
#      "first": "Drew",
#      "full": "Drew Timme",
#      "last": "Timme"
#    },
#    "player_id": 10141,
#    "player_key": "428.p.10141",
#    "position_type": "P",
#    "primary_position": "PF",
#    "status": "NA",
#    "status_full": "Not Active",
#    "uniform_number": 26,
#    "url": "https://sports.yahoo.com/nba/players/10141"
#  }),
#  Player({
#    "display_position": "SG",
#    "editorial_player_key": "nba.p.10144",
#    "editorial_team_abbr": "DET",
#    "editorial_team_full_name": "Detroit Pistons",
#    "editorial_team_key": "nba.t.8",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/detroit/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/25HF6dsGfamhOoHmFpjqFg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10144.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/25HF6dsGfamhOoHmFpjqFg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10144.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Malcolm",
#      "ascii_last": "Cazalon",
#      "first": "Malcolm",
#      "full": "Malcolm Cazalon",
#      "last": "Cazalon"
#    },
#    "player_id": 10144,
#    "player_key": "428.p.10144",
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 20,
#    "url": "https://sports.yahoo.com/nba/players/10144"
#  }),
#  Player({
#    "display_position": "PG",
#    "editorial_player_key": "nba.p.10145",
#    "editorial_team_abbr": "CLE",
#    "editorial_team_full_name": "Cleveland Cavaliers",
#    "editorial_team_key": "nba.t.5",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/cleveland/",
#    "eligible_positions": [
#      "PG"
#    ],
#    "has_player_notes": 1,
#    "has_recent_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/09tms7PK3jSSaln343s6fg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/10145.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/09tms7PK3jSSaln343s6fg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10122023/10145.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Craig",
#      "ascii_last": "Porter Jr.",
#      "first": "Craig",
#      "full": "Craig Porter Jr.",
#      "last": "Porter Jr."
#    },
#    "player_id": 10145,
#    "player_key": "428.p.10145",
#    "player_notes_last_timestamp": 1698842041,
#    "position_type": "P",
#    "primary_position": "PG",
#    "uniform_number": 40,
#    "url": "https://sports.yahoo.com/nba/players/10145"
#  }),
#  Player({
#    "display_position": "SG",
#    "editorial_player_key": "nba.p.10146",
#    "editorial_team_abbr": "LAL",
#    "editorial_team_full_name": "Los Angeles Lakers",
#    "editorial_team_key": "nba.t.13",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-lakers/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/h8yi_wcoB2tXwWKEHe5bxw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10146.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/h8yi_wcoB2tXwWKEHe5bxw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10146.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "D'Moi",
#      "ascii_last": "Hodge",
#      "first": "D'Moi",
#      "full": "D'Moi Hodge",
#      "last": "Hodge"
#    },
#    "player_id": 10146,
#    "player_key": "428.p.10146",
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 55,
#    "url": "https://sports.yahoo.com/nba/players/10146"
#  }),
#  Player({
#    "display_position": "PF",
#    "editorial_player_key": "nba.p.10147",
#    "editorial_team_abbr": "LAL",
#    "editorial_team_full_name": "Los Angeles Lakers",
#    "editorial_team_key": "nba.t.13",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/la-lakers/",
#    "eligible_positions": [
#      "PF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/GkzcYnQjn6H.MvKzOymbjg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10147.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/GkzcYnQjn6H.MvKzOymbjg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10242023/10147.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Colin",
#      "ascii_last": "Castleton",
#      "first": "Colin",
#      "full": "Colin Castleton",
#      "last": "Castleton"
#    },
#    "player_id": 10147,
#    "player_key": "428.p.10147",
#    "position_type": "P",
#    "primary_position": "PF",
#    "uniform_number": 14,
#    "url": "https://sports.yahoo.com/nba/players/10147"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.10148",
#    "editorial_team_abbr": "ATL",
#    "editorial_team_full_name": "Atlanta Hawks",
#    "editorial_team_key": "nba.t.1",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/atlanta/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "has_player_notes": 1,
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/0pMYlRi8CcYsnE9WwHo72A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/10148.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/0pMYlRi8CcYsnE9WwHo72A--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10092023/10148.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Miles",
#      "ascii_last": "Norris",
#      "first": "Miles",
#      "full": "Miles Norris",
#      "last": "Norris"
#    },
#    "player_id": 10148,
#    "player_key": "428.p.10148",
#    "player_notes_last_timestamp": 1698602525,
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 0,
#    "url": "https://sports.yahoo.com/nba/players/10148"
#  }),
#  Player({
#    "display_position": "SF,PF",
#    "editorial_player_key": "nba.p.10152",
#    "editorial_team_abbr": "CHA",
#    "editorial_team_full_name": "Charlotte Hornets",
#    "editorial_team_key": "nba.t.30",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/charlotte/",
#    "eligible_positions": [
#      "SF"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/0WNc9zmUcU6HnuC5.fQkfw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10102023/10152.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/0WNc9zmUcU6HnuC5.fQkfw--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10102023/10152.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Leaky",
#      "ascii_last": "Black",
#      "first": "Leaky",
#      "full": "Leaky Black",
#      "last": "Black"
#    },
#    "player_id": 10152,
#    "player_key": "428.p.10152",
#    "position_type": "P",
#    "primary_position": "SF",
#    "uniform_number": 12,
#    "url": "https://sports.yahoo.com/nba/players/10152"
#  }),
#  Player({
#    "display_position": "SG",
#    "editorial_player_key": "nba.p.10153",
#    "editorial_team_abbr": "CHI",
#    "editorial_team_full_name": "Chicago Bulls",
#    "editorial_team_key": "nba.t.4",
#    "editorial_team_url": "https://sports.yahoo.com/nba/teams/chicago/",
#    "eligible_positions": [
#      "SG"
#    ],
#    "headshot": {
#      "size": "small",
#      "url": "https://s.yimg.com/iu/api/res/1.2/h_FHhrO8NWRrr3tIBMJ0sg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10153.png"
#    },
#    "image_url": "https://s.yimg.com/iu/api/res/1.2/h_FHhrO8NWRrr3tIBMJ0sg--~C/YXBwaWQ9eXNwb3J0cztjaD0yMzM2O2NyPTE7Y3c9MTc5MDtkeD04NTc7ZHk9MDtmaT11bGNyb3A7aD02MDtxPTEwMDt3PTQ2/https://s.yimg.com/xe/i/us/sp/v/nba_cutout/players_l/10172023/10153.png",
#    "is_keeper": {
#      "status": false,
#      "cost": false,
#      "kept": false
#    },
#    "is_undroppable": 0,
#    "name": {
#      "ascii_first": "Onuralp",
#      "ascii_last": "Bitim",
#      "first": "Onuralp",
#      "full": "Onuralp Bitim",
#      "last": "Bitim"
#    },
#    "player_id": 10153,
#    "player_key": "428.p.10153",
#    "position_type": "P",
#    "primary_position": "SG",
#    "uniform_number": 17,
#    "url": "https://sports.yahoo.com/nba/players/10153"
#  })]

# %% [markdown]
# Get current week of the league

# %%
def get_game_week(game_id):
    today = datetime.date.today()
    game_weeks = yahoo_query.get_game_weeks_by_game_id(game_id)
    for game_week in game_weeks:
        start = game_week.start.split("-")
        end = game_week.end.split("-")
        start = datetime.date(int(start[0]), int(start[1]), int(start[2]))
        end = datetime.date(int(end[0]), int(end[1]), int(end[2]))
        if start <= today <= end:
            return game_week.week
    return None

# %%
yahoo_query.get_team_matchups(3)

# %%
from nba_api.stats.static import players

# %% [markdown]
# 2 Methods to get ID of a player, test later for speed

# %%
nba_players = players.get_players()
[player for player in nba_players if player["full_name"] == "Alperen Sengun"]
# Out:
# [{'id': 1630578,
#   'full_name': 'Alperen Sengun',
#   'first_name': 'Alperen',
#   'last_name': 'Sengun',
#   'is_active': True}]

# %%
players.find_players_by_full_name('alperen sengun')
# Out:
# [{'id': 1630578,
#   'full_name': 'Alperen Sengun',
#   'first_name': 'Alperen',
#   'last_name': 'Sengun',
#   'is_active': True}]

# %%
players.find_players_by_full_name('lebron james')
# Out:
# [{'id': 2544,
#   'full_name': 'LeBron James',
#   'first_name': 'LeBron',
#   'last_name': 'James',
#   'is_active': True}]

# %%
from nba_api.stats.endpoints import PlayerGameLog, PlayerDashboardByLastNGames, PlayerNextNGames

# %% [markdown]
# Get game log of player, includes stats, team played against, doesnt include games missed

# %%
PlayerGameLog(player_id=1630578).get_data_frames()[0]
# Out:
#   SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0     22023    1630578  0022300122  ...  19          9               1
# 1     22023    1630578  0022300096  ...  19        -10               1
# 2     22023    1630578  0022300083  ...  25         -4               1
# 3     22023    1630578  0022300066  ...  14         -4               1
#
# [4 rows x 27 columns]

# %%
PlayerGameLog(player_id=1630578, season='2022').get_data_frames()[0]
# Out:
#    SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0      22022    1630578  0022201222  ...  12         -4               1
# 1      22022    1630578  0022201202  ...  14          5               1
# 2      22022    1630578  0022201183  ...  20         15               1
# 3      22022    1630578  0022201171  ...  18         -5               1
# 4      22022    1630578  0022201155  ...  15         13               1
# ..       ...        ...         ...  ...  ..        ...             ...
# 70     22022    1630578  0022200094  ...  16         -1               1
# 71     22022    1630578  0022200080  ...  14         -8               1
# 72     22022    1630578  0022200033  ...   9         -8               1
# 73     22022    1630578  0022200024  ...  23         13               1
# 74     22022    1630578  0022200005  ...  15         -6               1
#
# [75 rows x 27 columns]

# %% [markdown]
# Get next N games of player, includes dates and team against

# %%
PlayerNextNGames(player_id=1630578, number_of_games=5, season_type_all_star="Regular Season").get_data_frames()[0]
# Out:
#       GAME_ID     GAME_DATE  HOME_TEAM_ID  ...  GAME_TIME HOME_WL VISITOR_WL
# 0  0022300137  NOV 04, 2023    1610612745  ...   08:00 PM     1-3        2-2
# 1  0022300153  NOV 06, 2023    1610612745  ...   08:00 PM     1-3        2-2
# 2  0022300163  NOV 08, 2023    1610612745  ...   08:00 PM     1-3        3-2
# 3  0022300011  NOV 10, 2023    1610612745  ...   08:00 PM     1-3        3-1
# 4  0022300182  NOV 12, 2023    1610612745  ...   07:00 PM     1-3        4-1
#
# [5 rows x 13 columns]

# %%
from nba_api.stats.static import teams

# %%
teams.get_teams()
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
#   'full_name': 'Dallas Mavericks',
#   'abbreviation': 'DAL',
#   'nickname': 'Mavericks',
#   'city': 'Dallas',
#   'state': 'Texas',
#   'year_founded': 1980},
#  {'id': 1610612743,
#   'full_name': 'Denver Nuggets',
#   'abbreviation': 'DEN',
#   'nickname': 'Nuggets',
#   'city': 'Denver',
#   'state': 'Colorado',
#   'year_founded': 1976},
#  {'id': 1610612744,
#   'full_name': 'Golden State Warriors',
#   'abbreviation': 'GSW',
#   'nickname': 'Warriors',
#   'city': 'Golden State',
#   'state': 'California',
#   'year_founded': 1946},
#  {'id': 1610612745,
#   'full_name': 'Houston Rockets',
#   'abbreviation': 'HOU',
#   'nickname': 'Rockets',
#   'city': 'Houston',
#   'state': 'Texas',
#   'year_founded': 1967},
#  {'id': 1610612746,
#   'full_name': 'Los Angeles Clippers',
#   'abbreviation': 'LAC',
#   'nickname': 'Clippers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1970},
#  {'id': 1610612747,
#   'full_name': 'Los Angeles Lakers',
#   'abbreviation': 'LAL',
#   'nickname': 'Lakers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612748,
#   'full_name': 'Miami Heat',
#   'abbreviation': 'MIA',
#   'nickname': 'Heat',
#   'city': 'Miami',
#   'state': 'Florida',
#   'year_founded': 1988},
#  {'id': 1610612749,
#   'full_name': 'Milwaukee Bucks',
#   'abbreviation': 'MIL',
#   'nickname': 'Bucks',
#   'city': 'Milwaukee',
#   'state': 'Wisconsin',
#   'year_founded': 1968},
#  {'id': 1610612750,
#   'full_name': 'Minnesota Timberwolves',
#   'abbreviation': 'MIN',
#   'nickname': 'Timberwolves',
#   'city': 'Minnesota',
#   'state': 'Minnesota',
#   'year_founded': 1989},
#  {'id': 1610612751,
#   'full_name': 'Brooklyn Nets',
#   'abbreviation': 'BKN',
#   'nickname': 'Nets',
#   'city': 'Brooklyn',
#   'state': 'New York',
#   'year_founded': 1976},
#  {'id': 1610612752,
#   'full_name': 'New York Knicks',
#   'abbreviation': 'NYK',
#   'nickname': 'Knicks',
#   'city': 'New York',
#   'state': 'New York',
#   'year_founded': 1946},
#  {'id': 1610612753,
#   'full_name': 'Orlando Magic',
#   'abbreviation': 'ORL',
#   'nickname': 'Magic',
#   'city': 'Orlando',
#   'state': 'Florida',
#   'year_founded': 1989},
#  {'id': 1610612754,
#   'full_name': 'Indiana Pacers',
#   'abbreviation': 'IND',
#   'nickname': 'Pacers',
#   'city': 'Indiana',
#   'state': 'Indiana',
#   'year_founded': 1976},
#  {'id': 1610612755,
#   'full_name': 'Philadelphia 76ers',
#   'abbreviation': 'PHI',
#   'nickname': '76ers',
#   'city': 'Philadelphia',
#   'state': 'Pennsylvania',
#   'year_founded': 1949},
#  {'id': 1610612756,
#   'full_name': 'Phoenix Suns',
#   'abbreviation': 'PHX',
#   'nickname': 'Suns',
#   'city': 'Phoenix',
#   'state': 'Arizona',
#   'year_founded': 1968},
#  {'id': 1610612757,
#   'full_name': 'Portland Trail Blazers',
#   'abbreviation': 'POR',
#   'nickname': 'Trail Blazers',
#   'city': 'Portland',
#   'state': 'Oregon',
#   'year_founded': 1970},
#  {'id': 1610612758,
#   'full_name': 'Sacramento Kings',
#   'abbreviation': 'SAC',
#   'nickname': 'Kings',
#   'city': 'Sacramento',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612759,
#   'full_name': 'San Antonio Spurs',
#   'abbreviation': 'SAS',
#   'nickname': 'Spurs',
#   'city': 'San Antonio',
#   'state': 'Texas',
#   'year_founded': 1976},
#  {'id': 1610612760,
#   'full_name': 'Oklahoma City Thunder',
#   'abbreviation': 'OKC',
#   'nickname': 'Thunder',
#   'city': 'Oklahoma City',
#   'state': 'Oklahoma',
#   'year_founded': 1967},
#  {'id': 1610612761,
#   'full_name': 'Toronto Raptors',
#   'abbreviation': 'TOR',
#   'nickname': 'Raptors',
#   'city': 'Toronto',
#   'state': 'Ontario',
#   'year_founded': 1995},
#  {'id': 1610612762,
#   'full_name': 'Utah Jazz',
#   'abbreviation': 'UTA',
#   'nickname': 'Jazz',
#   'city': 'Utah',
#   'state': 'Utah',
#   'year_founded': 1974},
#  {'id': 1610612763,
#   'full_name': 'Memphis Grizzlies',
#   'abbreviation': 'MEM',
#   'nickname': 'Grizzlies',
#   'city': 'Memphis',
#   'state': 'Tennessee',
#   'year_founded': 1995},
#  {'id': 1610612764,
#   'full_name': 'Washington Wizards',
#   'abbreviation': 'WAS',
#   'nickname': 'Wizards',
#   'city': 'Washington',
#   'state': 'District of Columbia',
#   'year_founded': 1961},
#  {'id': 1610612765,
#   'full_name': 'Detroit Pistons',
#   'abbreviation': 'DET',
#   'nickname': 'Pistons',
#   'city': 'Detroit',
#   'state': 'Michigan',
#   'year_founded': 1948},
#  {'id': 1610612766,
#   'full_name': 'Charlotte Hornets',
#   'abbreviation': 'CHA',
#   'nickname': 'Hornets',
#   'city': 'Charlotte',
#   'state': 'North Carolina',
#   'year_founded': 1988}]
