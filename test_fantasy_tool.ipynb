# %%
import json
import datetime

from os import path
from scipy import stats
from yfpy import Data
from yfpy.logger import get_logger
from yfpy.query import YahooFantasySportsQuery

from nba_api.stats.endpoints import PlayerGameLog, PlayerDashboardByLastNGames, PlayerNextNGames
from nba_api.stats.static import players, teams

class Normal_Distribution:
    def __init__(self, samples=None, num_samples=None, mean=None, variance=None, sd=None):
        if samples:
            self.num_samples = len(samples)
            self.mean = stats.tmean(samples)
            self.variance = stats.tvar(samples)
            self.sd = stats.sqrt(self.variance)

        else:
            self.num_samples = num_samples
            self.mean = mean
            self.variance = variance
            self.sd = sd

    @classmethod
    def combine(cls, dist1, dist2, weight1, weight2):

        num_samples = dist1.num_samples + dist2.num_samples
        mean = dist1.mean * weight1 + dist2.mean * weight2
        variance = (dist1.sd * weight1)^2 + (dist2.sd * weight2)^2
        sd = stats.sqrt(sd)

        return Normal_Distribution(num_samples=num_samples, mean=mean, variance=variance, sd=sd)

class Player:
    def __init__(self, full_name, position, players):
        print(full_name)
        self.full_name = full_name
        self.position = position
        self.id = players.find_players_by_full_name(full_name)[0]['id']
        self.categories = {}

    def calculate_dist(query, category):
        pass

    def get_category_dists(self, categories, min_mins=7, cume_stats_vs_teams=None, cume_stats_by_location=None):
        cume_stats = {c:[] for c in categories}
        
        for game in PlayerGameLog(player_id=self.id).get_normalized_dict()["PlayerGameLog"]:
            if game['MIN'] < min_mins:
                continue
            _ ,location, opponent = game['MATCHUP'].split(' ')
            for cat in categories:
                cume_stats[cat]['val'].append(game[cat])
                if cume_stats_vs_teams:
                    cume_stats_vs_teams[opponent][cat].append(game[cat])
                if cume_stats_by_location:
                    cume_stats_by_location[location][cat].append(game[cat])

        for cat in categories:
            self.categories[cat] = Normal_Distribution(samples=cume_stats[cat])

class Team:
    def __init__(self, owner_id):
        self.owner_id = owner_id
        self.players = []
        self.category_rankings = {}

class League:
    def __init__(self, auth_dir, league_id, game_id, categories):

        with open(path.join(auth_dir, r"private.json")) as f:
            private = json.load(f)
        self.yahoo_query = YahooFantasySportsQuery(
                                auth_dir,
                                league_id,
                                game_code= 'nba',
                                game_id = game_id,
                                offline=False,
                                all_output_as_json_str=False,
                                consumer_key=private["consumer_key"],
                                consumer_secret=private["consumer_secret"],
                                browser_callback=True)
        self.categories = categories
        self.nba_players = players.get_players()
        print(1)
        self.cume_stats_vs_teams = {t['abbreviation']:{c:[] for c in categories} for t in teams.get_teams()}
        print(2)
        self.cume_stats_by_location = {l:{c:[] for c in categories} for l in ['vs', '@']}
        print(3)
        self.all_players = [Player(p.full_name, p.primary_position, self.nba_players) for p in self.yahoo_query.get_league_players()]

# %%
CATEGORIES = ['PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'FG3M', 'FGM', 'FGA', 'FTM', 'FTA']
auth_dir = r"auth/"
league_id = r"101582"
game_id  = 428
leauge = League(auth_dir, league_id, game_id, CATEGORIES)
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:192, in YahooFantasySportsQuery.get_response(self, url)
#     191 try:
# --> 192     response_json = response.json()
#     193     logger.debug(f"Response (JSON): {response_json}")
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# c:\Users\chena\Desktop\FantasyBasketball\test_fantasy_tool.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> league_id = r"101582"
#       <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> game_id  = 428
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> leauge = League(auth_dir, league_id, game_id, CATEGORIES)
#
# c:\Users\chena\Desktop\FantasyBasketball\test_fantasy_tool.ipynb Cell 2 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=90'>91</a> self.cume_stats_by_location = {l:{c:[] for c in categories} for l in ['vs', '@']}
#      <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=91'>92</a> print(3)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chena/Desktop/FantasyBasketball/test_fantasy_tool.ipynb#W1sZmlsZQ%3D%3D?line=92'>93</a> self.all_players = [Player(p.full_name, p.primary_position, self.nba_players) for p in self.yahoo_query.get_league_players()]
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:1374, in YahooFantasySportsQuery.get_league_players(self, player_count_limit, player_count_start, is_retry)
#    1370 while not all_players_retrieved:
#    1372     try:
#    1373         league_player_query_data = self.query(
# -> 1374             f"https://fantasysports.yahooapis.com/fantasy/v2/league/{self.get_league_key()}/players;"
#    1375             f"start={league_player_count};count={league_player_retrieval_limit if not is_retry else 1}",
#    1376             ["league", "players"]
#    1377         )
#    1379         league_players = (league_player_query_data if isinstance(league_player_query_data, list) else
#    1380                           [league_player_query_data])
#    1381         league_player_count_from_query = len(league_players)
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:774, in YahooFantasySportsQuery.get_league_key(self, season)
#     772     return f"{self.get_game_key_by_season(season)}.l.{self.league_id}"
#     773 elif self.game_id:
# --> 774     return f"{self.get_game_metadata_by_game_id(self.game_id).game_key}.l.{self.league_id}"
#     775 else:
#     776     logger.warning(
#     777         "No game id or season/year provided, defaulting to current fantasy season.")
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:603, in YahooFantasySportsQuery.get_game_metadata_by_game_id(self, game_id)
#     575 def get_game_metadata_by_game_id(self, game_id: int) -> Game:
#     576     """Retrieve game metadata for specific game by ID.
#     577
#     578     Args:
#    (...)
#     601
#     602     """
# --> 603     return self.query(
#     604         f"https://fantasysports.yahooapis.com/fantasy/v2/game/{game_id}/metadata",
#     605         ["game"],
#     606         Game
#     607     )
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:262, in YahooFantasySportsQuery.query(self, url, data_key_list, data_type_class, sort_function)
#     243 """Base query class to retrieve requested data from the Yahoo fantasy sports REST API.
#     244
#     245 Args:
#    (...)
#     259
#     260 """
#     261 if not self.offline:
# --> 262     response = self.get_response(url)
#     263     raw_response_data = response.json().get(self.fantasy_content_data_field)
#     265     # iterate through list of data keys and drill down to final desired data field
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\yfpy\query.py:195, in YahooFantasySportsQuery.get_response(self, url)
#     193     logger.debug(f"Response (JSON): {response_json}")
#     194 except JSONDecodeError:
# --> 195     response.raise_for_status()
#     197 try:
#     198     if (status_code // 100) != 2:
#     199         # handle if the yahoo query returns an error
#
# File c:\Users\chena\anaconda3\envs\fantasy\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 502 Server Error: Malformed Server Response Status for url: https://fantasysports.yahooapis.com/fantasy/v2/game/428/metadata?format=json
